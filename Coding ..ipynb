# %%
#Write a Python program that prints numbers from 1 to 5.

for i in range(1,6):  
    print(i,end=" ")
# Out:
# 1 2 3 4 5

# %%
# Write a Python program to print the first 5 even numbers. 
for i in range(1, 6):
    print(i * 2, end=" ")
# Out:
# 2 4 6 8 10

# %%
#Write a Python program to print the sum of numbers from 1 to 10. 
total = 0

for i in range(1, 11):
    total = total + i

print("Sum:", total)
# Out:
# Sum: 55

# %%
# Write a Python function to find the factorial of 5. 

fact=1
for i in range(1,6):
    fact=fact*i
print(fact)
# Out:
# 120

# %%
#5.Write a Python program to check if a number is prime. 

num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number:  7
# 7 is a prime number
