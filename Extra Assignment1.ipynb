# %%
print("Hope ai")
# Out:
# Hope ai

# %%
name=input("Enter your institute name:")

# %%
name=input("Enter your name:")
age =input("age:")
name= input("Enter your School name:")
name=input("Enter your Degree:")
# Out:
# Enter your name: kader
# age: 24
# Enter your School name: telc
# Enter your Degree: msc

# %%
Num1=43
Num2=34
Add=77
print('Number1=',Num1)
print('Number2=',Num2)
print('Add',Add)
# Out:
# Number1= 43
# Number2= 34
# Add 77

# %%
Num1=43
Num2=34
sub=9
print('Number1=',Num1)
print('Number2=',Num2)
print('sub',sub)
# Out:
# Number1= 43
# Number2= 34
# sub 9

# %%
Num1=63
Num2=97
Mul=6111
print('Number1=',Num1)
print('Number2=',Num2)
print('Mul',Mul)
# Out:
# Number1= 63
# Number2= 97
# Mul 6111

# %%
Num1=76
Num2=31
FloorDiv=2
print('Number1=',Num1)
print('Number2=',Num2)
print('FloorDiv',FloorDiv)
# Out:
# Number1= 76
# Number2= 31
# FloorDiv 2

# %%
a = 76
b = 31
result = a % b
print("Remainder:", result)
# Out:
# Remainder: 14

# %%
a = 4
b = 4
result = a ** b
print("Remainder:", result)
# Out:
# Remainder: 256
