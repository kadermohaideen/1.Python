# %%
value=(int)(input("Value="))
if(value==10):
      print("Correct")
# Out:
# Value= 10
# Correct

# %%
# Check the password, using if and else
Paswordvl=(input("Enter the password="))
if(Paswordvl=="HOPE@123"):
      print("Your password is Correct")
else:
      print("Your password is wrong")
# Out:
# Enter the password= Hope@123
# Your password is wrong

# %%
# Catagory the people by their age like children, adult, citizen, senior citizen...
ageVal=(int)(input("Enter your Age"))
print("age:",ageVal)
if ageVal < 18: 
    print ("Children")
elif  ageVal >=18 and ageVal <= 23:
    print ("Adult")
elif  ageVal >=23 and ageVal <= 60:
    print ("Citizen")
elif  ageVal >=60 and ageVal <= 80:
    print ("senior citizen")
# Out:
# Enter your Age 34
# age: 34
# Citizen

# %%
#Find whether given number is positive or Negative 
numValu=(int)(input("Valu="))
if(numValu>=1):
      print("Positive")
elif(numValu<0):
    print("Negative")
# Out:
# Valu= 1
# Positive

# %%
# Extract the last digit using N % 10
divValue=(int)(input("Value="))
last_digit = divValue % 10
# Check for the last digit
if last_digit == 0 or last_digit == 5:
    print(divValue," is divisible by 5")
else:
    print(divValue," is not divisible by 5")
# Out:
# Value= 4
# 4  is not divisible by 5
